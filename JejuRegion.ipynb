# %%
import pandas as pd
df=pd.read_excel("jeju place2.xlsx")
del df['Unnamed: 0']

# %%
df
# Out:
#                      콘텐츠ID 콘텐츠분류                   제목  \
# 0     CNTS_000000000020419   음식점               초밥군커피씨
# 1     CNTS_000000000022944   음식점                 73st
# 2     CNTS_000000000020436   음식점                호돌이식당
# 3     CNTS_000000000021195   음식점             비양도 올레카페
# 4     CNTS_000000000020732   음식점              협재삼춘네횟집
# ...                    ...   ...                  ...
# 3624  CNTS_000000000022182   음식점  몽키비치클럽 Monkey Beach
# 3625  CNTS_000000000022252    숙박               힐링캠프펜션
# 3626  CNTS_000000000022237   음식점                 유나카페
# 3627  CNTS_200000000008003   관광지               동백포레스트
# 3628  CNTS_200000000012075   관광지           헌마공신김만일기념관
#
#                             지번주소                     도로명주소    지역분류         위도  \
# 0             제주특별자치도 제주시 흥운길 46        제주특별자치도 제주시 흥운길 46     NaN  33.512722
# 1         제주특별자치도 제주시 해안동 1977-1      제주특별자치도 제주시 해안마을길 73     NaN  33.456950
# 2       제주특별자치도 제주시 한림읍 협재리 3026  제주특별자치도 제주시 한림읍 비양도길 284   제주시서부  33.406414
# ...

# %%
제주시 = ['일도','이도','삼도','용담','화북','삼양','노형','외도','이호','도두','도남','내도','삼양','이호','추자','건입','연동',
      '회천','오라','아라','해안','흥운','도평','봉개','용강','영평','월평','오등']
제주시서부 = ['한경면',' 한림읍',' 애월읍','애월']
서귀포시서부 =['대정읍','안덕면','상예동','하예동','회수동','상예']
서귀포시 =['서귀동','법환동','하효동','중문동','강정동','하원동','색달동','토평동','서홍동','서호동','상효동','동홍동','보목동',
      '도순동','대포동','서호동','호근동','신효동','호근동']
서귀포시동부 =['남원읍', '표선면', '성산읍','성산']
제주시동부 =['조천읍', '구좌읍','우도']


arr=[제주시,제주시서부,서귀포시서부,서귀포시,서귀포시동부,제주시동부]
arrname=['제주시','제주시서부','서귀포시서부','서귀포시','서귀포시동부','제주시동부']

# %%
# 데이터 프레임 전체 포문
for i in range(0, len(df)):
    # 동서남북부 
    for j in range(0,len(arr)):
        #문자열 찾기
        for k in range(0,len(arr[j])):
            if df.iloc[i,3].find(arr[j][k])!=-1:
                df.iat[i,5]=arrname[j]

# %%
df.지역분류.isnull().sum()
# Out:
# 68

# %%
df[df['지역분류'].isnull()]
# Out:
#                      콘텐츠ID 콘텐츠분류                 제목                 지번주소  \
# 47    CNTS_000000000001011   음식점                예소담    제주특별자치도 제주시 천수로 6
# 138   CNTS_000000000001373   음식점                 덤장   제주특별자치도 제주시 용문로 48
# 248   CONT_000000000501414   음식점           한우네백년해장국    제주특별자치도 제주시 신산로 6
# 252   CNTS_000000000001480   음식점       돈마구이해장국(연동점)   제주특별자치도 제주시 삼동길 60
# 343   CNTS_000000000020638   음식점            진대감12제주  제주특별자치도 제주시 광평동로 45
# ...                    ...   ...                ...                  ...
# 3545  CNTS_000000000022848   관광지               도령모루              제주특별자치도
# 3546  CNTS_000000000022846   관광지  연미마을(오라리 방화사건 현장)              제주특별자치도
# 3547  CNTS_000000000022872   관광지               종남마을              제주특별자치도
# 3579  CNTS_000000000022063   관광지          관음사 템플스테이         제주시 산록북로 660
# 3610  CNTS_000000000022412   음식점              갈치 카페     제주 서귀포시 중문관광로 31
#
#                     도로명주소 지역분류         위도          경도   평점   조회수  좋아요수  리뷰수  \
# ...

# %%
df1=df
for i in range(0,len(df1)):
    if df1.iloc[i,3]=='제주특별자치도': df2=df1.drop(i)

# %%
df1
# Out:
#                      콘텐츠ID 콘텐츠분류                   제목  \
# 0     CNTS_000000000020419   음식점               초밥군커피씨
# 1     CNTS_000000000022944   음식점                 73st
# 2     CNTS_000000000020436   음식점                호돌이식당
# 3     CNTS_000000000021195   음식점             비양도 올레카페
# 4     CNTS_000000000020732   음식점              협재삼춘네횟집
# ...                    ...   ...                  ...
# 3624  CNTS_000000000022182   음식점  몽키비치클럽 Monkey Beach
# 3625  CNTS_000000000022252    숙박               힐링캠프펜션
# 3626  CNTS_000000000022237   음식점                 유나카페
# 3627  CNTS_200000000008003   관광지               동백포레스트
# 3628  CNTS_200000000012075   관광지           헌마공신김만일기념관
#
#                             지번주소                     도로명주소    지역분류         위도  \
# 0             제주특별자치도 제주시 흥운길 46        제주특별자치도 제주시 흥운길 46     제주시  33.512722
# 1         제주특별자치도 제주시 해안동 1977-1      제주특별자치도 제주시 해안마을길 73     제주시  33.456950
# 2       제주특별자치도 제주시 한림읍 협재리 3026  제주특별자치도 제주시 한림읍 비양도길 284   제주시서부  33.406414
# ...

# %%
df1[df1['지역분류'].isnull()]
# Out:
#                      콘텐츠ID 콘텐츠분류                 제목                 지번주소  \
# 47    CNTS_000000000001011   음식점                예소담    제주특별자치도 제주시 천수로 6
# 138   CNTS_000000000001373   음식점                 덤장   제주특별자치도 제주시 용문로 48
# 248   CONT_000000000501414   음식점           한우네백년해장국    제주특별자치도 제주시 신산로 6
# 252   CNTS_000000000001480   음식점       돈마구이해장국(연동점)   제주특별자치도 제주시 삼동길 60
# 343   CNTS_000000000020638   음식점            진대감12제주  제주특별자치도 제주시 광평동로 45
# ...                    ...   ...                ...                  ...
# 3545  CNTS_000000000022848   관광지               도령모루              제주특별자치도
# 3546  CNTS_000000000022846   관광지  연미마을(오라리 방화사건 현장)              제주특별자치도
# 3547  CNTS_000000000022872   관광지               종남마을              제주특별자치도
# 3579  CNTS_000000000022063   관광지          관음사 템플스테이         제주시 산록북로 660
# 3610  CNTS_000000000022412   음식점              갈치 카페     제주 서귀포시 중문관광로 31
#
#                     도로명주소 지역분류         위도          경도   평점   조회수  좋아요수  리뷰수  \
# ...

# %%
df1.to_excel("jeju place4.xlsx")
